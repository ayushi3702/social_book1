# %%
import pandas as pd
from sqlalchemy import create_engine, text
import psycopg2

# %%
engine = create_engine('postgresql+psycopg2://postgres:ayushi2002@localhost:5432/django_project')
# engine = create_engine(dialect+driver://username:password@host:port/database_name)

# %%
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5432/django_project)

# %%
df = pd.read_sql_table("page_customuser", engine, columns=['is_superuser', 'username', 'email', 'is_staff', 'gender', 'fullname', 'public_visibility'])
df
# Out:
#    is_superuser username             email  is_staff gender    fullname
# 0          True   prasad  prasad@gmail.com      True                     \
# 1         False    user3   user3@gmail.com     False      M  user three
# 2         False     user    user@gmail.com     False      F        user
# 3         False    user1   user1@gmail.com     False      M    user one
# 4         False       aa       a@gmail.com     False      F       aa aa
# 5         False       bb       b@gmail.com     False      M       bb bb
# 6         False       cc       c@gmail.com     False      M       cc cc
# 7         False       dd       d@gmail.com     False      M        dddd
# 8         False    user2   user2@gmail.com     False      M    user two
# 9         False    user4   user4@gmail.com     False      F   user four
#
#    public_visibility
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# ...

# %%
query = """
                            SELECT * from "public"."page_customuser"
                        """
df1=pd.read_sql_query(query, engine)
df1
# Out:
#    id                                           password
# 0   2  pbkdf2_sha256$600000$yqtnBV9FMIEwPdUWc5pxBe$Ps...  \
# 1   1  pbkdf2_sha256$600000$mEEWdRsdJHkhBHmOZVY2qM$oy...
# 2   3  pbkdf2_sha256$600000$EpKrLucPU764pc6jTYJQ6h$77...
# 3   4  pbkdf2_sha256$600000$PNjfxaTCYkw0GeACGmEEdR$1r...
# 4   5  pbkdf2_sha256$600000$ojpuoGDFxY8KicgCBbgSf9$ax...
# 5   6  pbkdf2_sha256$600000$oLC5aAGhmuzoyDxnpqnOao$vX...
# 6   7  pbkdf2_sha256$600000$N05uaWRsCjEULqnayriony$QF...
# 7   8  pbkdf2_sha256$600000$OX4ZtkSywHWnij2Y4nDvWG$Zu...
# 8   9  pbkdf2_sha256$600000$rgCaQBTIqNV6Yj0rcqkSuM$xI...
# 9  10  pbkdf2_sha256$600000$uTn7uDUKaiLZAsXNG4kvs5$F1...
#
#                         last_login  is_superuser username first_name
# 0 2023-07-06 07:10:06.171295+00:00          True   prasad             \
# 1 2023-07-06 07:28:04.410472+00:00         False    user3
# 2                              NaT         False     user
# 3 2023-07-06 07:45:52.925505+00:00         False    user1
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.shape
# Out:
# (10, 14)

# %%
df2 = pd.DataFrame(df1, columns=['username', 'email', 'gender', 'is_superuser'])
df2
# Out:
#   username             email gender  is_superuser
# 0   prasad  prasad@gmail.com                 True
# 1    user3   user3@gmail.com      M         False
# 2     user    user@gmail.com      F         False
# 3    user1   user1@gmail.com      M         False
# 4       aa       a@gmail.com      F         False
# 5       bb       b@gmail.com      M         False
# 6       cc       c@gmail.com      M         False
# 7       dd       d@gmail.com      M         False
# 8    user2   user2@gmail.com      M         False
# 9    user4   user4@gmail.com      F         False

# %%
filtered_data = db[(db['is_superuser'] == True)]
filtered_data
# Out:
#    id                                           password
# 0   2  pbkdf2_sha256$600000$yqtnBV9FMIEwPdUWc5pxBe$Ps...  \
#
#                         last_login  is_superuser username first_name
# 0 2023-07-06 07:10:06.171295+00:00          True   prasad             \
#
#   last_name             email  is_staff  is_active
# 0            prasad@gmail.com      True       True  \
#
#                        date_joined gender fullname  public_visibility
# 0 2023-07-06 07:08:55.362858+00:00                              False

# %%
filtered_data1 = db[(db['gender'] == 'M')]
filtered_data1
# Out:
#    id                                           password
# 1   1  pbkdf2_sha256$600000$mEEWdRsdJHkhBHmOZVY2qM$oy...  \
#
#                         last_login  is_superuser username first_name
# 1 2023-07-06 07:28:04.410472+00:00         False    user3             \
#
#   last_name            email  is_staff  is_active
# 1            user3@gmail.com     False       True  \
#
#                        date_joined gender    fullname  public_visibility
# 1 2023-07-06 07:02:40.557732+00:00      M  user three              False

# %%
df3 = pd.DataFrame(df)
df3['gender'].replace('M', 'Male', inplace=True)
df3
# Out:
#    is_superuser username             email  is_staff gender    fullname
# 0          True   prasad  prasad@gmail.com      True                     \
# 1         False    user3   user3@gmail.com     False   Male  user three
# 2         False     user    user@gmail.com     False      F        user
# 3         False    user1   user1@gmail.com     False   Male    user one
# 4         False       aa       a@gmail.com     False      F       aa aa
# 5         False       bb       b@gmail.com     False   Male       bb bb
# 6         False       cc       c@gmail.com     False   Male       cc cc
# 7         False       dd       d@gmail.com     False   Male        dddd
# 8         False    user2   user2@gmail.com     False   Male    user two
# 9         False    user4   user4@gmail.com     False      F   user four
#
#    public_visibility
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# ...
